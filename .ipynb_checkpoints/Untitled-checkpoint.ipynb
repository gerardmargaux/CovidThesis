# %%
import pandas as pd
import data_collection as dc
import prediction_model as pred
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-499970104e89> in <module>
#       1 import pandas as pd
#       2 import data_collection as dc
# ----> 3 import prediction_model as pred
#
# ~/code/thesis/CovidThesis/src/prediction_model.py in <module>
#       9 import pickle
#      10 from tensorflow.python.keras.models import load_model
# ---> 11 from src.data_collection import *
#      12 import urllib
#      13 import io
#
# ModuleNotFoundError: No module named 'src'

# %%
def add_lag_diff(df, begin, end, interval, dropna=True):
    columns = df.columns
    for column in columns:
        if column.lower() == 'date':
            continue
        for i in range(begin, end, interval):
            df[f'{column}_{i}_lag'] = df[column].shift(i)  # lags in days
            df[f'{column}_{i}_diff'] = df[f'{column}_{i}_lag'].diff()  # difference
    return df.dropna() if dropna else df

# %%
df = pd.read_csv('../data/trends/model/FR-A-Fièvre.csv')
print(df)
add_lag_diff(df, 7, 10, 1)
# Out:
#            date  /m/0cjf0
# 0    2020-03-01        37
# 1    2020-03-02        19
# 2    2020-03-03        39
# 3    2020-03-04        43
# 4    2020-03-05        35
# ..          ...       ...
# 227  2020-10-14        17
# 228  2020-10-15        26
# 229  2020-10-16        27
# 230  2020-10-17        10
# 231  2020-10-18        24
#
# [232 rows x 2 columns]
#            date  /m/0cjf0  /m/0cjf0_7_lag  /m/0cjf0_7_diff  /m/0cjf0_8_lag  \
# 10   2020-03-11        54            43.0              4.0            39.0
# 11   2020-03-12        50            35.0             -8.0            43.0
# 12   2020-03-13        36            27.0             -8.0            35.0
# 13   2020-03-14        58            38.0             11.0            27.0
# 14   2020-03-15        58            30.0             -8.0            38.0
# ..          ...       ...             ...              ...             ...
# 227  2020-10-14        17            32.0             -1.0            33.0
# 228  2020-10-15        26             0.0            -32.0            32.0
# 229  2020-10-16        27             9.0              9.0             0.0
# 230  2020-10-17        10            19.0             10.0             9.0
# 231  2020-10-18        24            14.0             -5.0            19.0
#
#      /m/0cjf0_8_diff  /m/0cjf0_9_lag  /m/0cjf0_9_diff
# 10              20.0            19.0            -18.0
# 11               4.0            39.0             20.0
# 12              -8.0            43.0              4.0
# 13              -8.0            35.0             -8.0
# 14              11.0            27.0             -8.0
# ..               ...             ...              ...
# 227             25.0             8.0             -1.0
# 228             -1.0            33.0             25.0
# 229            -32.0            32.0             -1.0
# 230              9.0             0.0            -32.0
# 231             10.0             9.0              9.0
#
# [222 rows x 8 columns]
